# %% [markdown]
# # Questions
#
# - How would you visualize the distribution of wine quality scores?
# - What type of plot would be most effective to show the relationship between alcohol content and wine quality?
# - How would you visualize the relationship between pH and fixed acidity?
# - Design a visualization to compare the distributions of free sulfur dioxide and total sulfur dioxide.
# - What type of plot would you use to identify potential outliers in the chlorides variable?
# - Create a visualization that shows how wine quality varies with both alcohol content and density.
# - How would you visualize the relationship between volatile acidity and citric acid for different quality levels?
# - Create a plot that shows how the average levels of sulphates and alcohol change across different quality scores.
# - How would you visualize the proportion of wines in each quality category?
# - Create a correlation heatmap for all numeric variables.
# - Design a plot to explore whether there's a clear separation between high-quality and low-quality wines based on any two variables of your choice.
# - Create a visualization that compares the composition of the highest-rated wines (quality 9-10) with the lowest-rated wines (quality 0-3).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
plt.style.use('ggplot')

# %%
df = pd.read_csv('./data/winequality-red.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df['quality'].describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
df['quality'].plot(kind='hist', bins=5)
# df['quality'].plot(kind='box')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# the distribution of the wine quality is skewed to the left, with an average of 5.64. This data sample has the good wine quality

# %%
df['alcohol'].describe()
# Out:
# count    1599.000000
# mean       10.422983
# std         1.065668
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
df['alcohol'].plot(kind='hist', bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
x = df['alcohol']
y = df['quality']

plt.scatter(x, y)
plt.title('Alcohol Content vs Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality')
plt.show()

# %% [markdown]
# there's a small correlation between the content of alcohol to the quality of the wine

# %%
display(df['quality'].plot(kind='hist', bins=5)) #depricated
# Out:
# <Axes: ylabel='Frequency'>

# %%
display(df['alcohol'].plot(kind='hist', bins=5)) #depricated
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['fixed acidity'].describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
df['pH'].describe()
# Out:
# count    1599.000000
# mean        3.311113
# std         0.154386
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
y = df['pH']
x = df['fixed acidity']

plt.scatter(x, y)
plt.ylabel('pH')
plt.xlabel('fixed acidity')
# Out:
# Text(0.5, 0, 'fixed acidity')

# %% [markdown]
# as the fixed acidity increase, the pH of the wine decrease

# %%
df['free sulfur dioxide'].describe()
# df['free sulfur dioxide'].plot(kind='box')
# Out:
# count    1599.000000
# mean       15.874922
# std        10.460157
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
df['normalized_free'] =  (df['free sulfur dioxide'] - df['free sulfur dioxide'].mean())/df['free sulfur dioxide'].std()
df['normalized_free'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['normalized_total'] = (df['total sulfur dioxide'] - df['total sulfur dioxide'].mean())/df['total sulfur dioxide'].std()
df['normalized_total'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['total sulfur dioxide'].describe()
df[['normalized_total', 'normalized_free']].plot(kind='box')
# Out:
# <Axes: >

# %%
df['chlorides'].plot(kind='box')
# Out:
# <Axes: >

# %%
#(Mean + 2*SD) AND (Mean - 2*SD)
upper = (df['chlorides'].quantile(0.75)) + ((df['chlorides'].quantile(0.75)-df['chlorides'].quantile(0.25)) * 1.5)
lower = (df['chlorides'].quantile(0.25)) - ((df['chlorides'].quantile(0.75)-df['chlorides'].quantile(0.25)) * 1.5)

df[(df['chlorides'] >= lower) & (df['chlorides'] <= upper)]['chlorides']
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
#         ...
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# Name: chlorides, Length: 1487, dtype: float64

# %%
df['quality'].plot(kind='hist', bins=3)
# Out:
# <Axes: ylabel='Frequency'>

# %%
def category(input_):
    if input_ < 5:
        return 'L'
    elif (input_ >= 5) & (input_ < 7):
        return 'M'
    elif input_ >= 7:
        return 'H'
    else:
        return 'N/A'

# %%
df['Quality Category'] = df['quality'].apply(category)
df['Quality Category'].value_counts()
# Out:
# Quality Category
# M    1319
# H     217
# L      63
# Name: count, dtype: int64

# %%
sns.pairplot(df[['alcohol','density']], hue='Quality Category')

# %%
# df[df['Quality Category'] == 'M'][['volatile acidity']]
plt.scatter(df[df['Quality Category'] == 'H'][['volatile acidity']], df[df['Quality Category'] == 'H'][['citric acid']], alpha=0.3, color='green')
plt.scatter(df[df['Quality Category'] == 'M'][['volatile acidity']], df[df['Quality Category'] == 'M'][['citric acid']], alpha=0.1, color='red')
plt.scatter(df[df['Quality Category'] == 'L'][['volatile acidity']], df[df['Quality Category'] == 'L'][['citric acid']], alpha=0.3, color='blue')

# %%
df[['sulphates','alcohol']].mean()
# Out:
# sulphates     0.658149
# alcohol      10.422983
# dtype: float64

# %%
df.groupby('Quality Category')[['sulphates', 'alcohol']].mean().plot(kind='line')
# Out:
# <Axes: xlabel='Quality Category'>

# %%
x = np.linspace(0, 10, 5)
y = np.sin(x)

plt.plot(x, y)

# %%
plt.axhline(df[df['Quality Category'] == 'H']['sulphates'].mean(), linestyle='--', color='firebrick')
plt.axhline(df[df['Quality Category'] == 'M']['sulphates'].mean(), linestyle='--', color='steelblue')
plt.axhline(df[df['Quality Category'] == 'L']['sulphates'].mean(), linestyle='--', color='forestgreen')

# plt.plot(df[df['Quality Category'] == 'H']['sulphates'], alpha=0.5)
# plt.plot(df[df['Quality Category'] == 'H']['alcohol'])

# %%
plt.axhline(df[df['Quality Category'] == 'H']['alcohol'].mean(), linestyle='--', color='firebrick')
plt.axhline(df[df['Quality Category'] == 'M']['alcohol'].mean(), linestyle='--', color='steelblue')
plt.axhline(df[df['Quality Category'] == 'L']['alcohol'].mean(), linestyle='--', color='forestgreen')

# %%
a= df[df['Quality Category'] == 'H']['sulphates'].mean()
b= df[df['Quality Category'] == 'H']['alcohol'].mean()
c= df[df['Quality Category'] == 'M']['sulphates'].mean()
d= df[df['Quality Category'] == 'M']['alcohol'].mean()
e= df[df['Quality Category'] == 'L']['sulphates'].mean()
f= df[df['Quality Category'] == 'L']['alcohol'].mean()

# %%
plt.plot(a, b)
plt.plot(c, d)
plt.plot(e, f)
